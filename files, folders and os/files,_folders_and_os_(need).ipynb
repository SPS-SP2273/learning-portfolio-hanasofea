# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %% [markdown]
# ### 1.2 More about relative paths

# %%
.\data-files\data-01.txt # one folder below #

# %%
..\data-files\data-01.txt # one folder above #

# %% [markdown]
# ### 1.3 Path separator

# %%
# Your code here

# %% [markdown]
# ### Text files vs Binary files

# %%
# Your code here

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
with open('spectrum-01.txt', 'r') as file:
    file_content = file.read()

print(file_content)
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'
with open('my-text-once.txt', 'w') as file:
    file.write(text)

# %%
with open('my-text-lines.txt', 'w') as file:   # don't understand #
    for line in text.splitlines(): 
        file.writelines(line)

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os
import glob
import shutil

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# ./all-data/sg-data/data-01.txt

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating people/Jonh
# Creating people/Paul
# Creating people/Ringo

# %% [markdown]
# ### 2.4 Checking for existence

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people/Jonh already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people/Jonh already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %% [markdown]
# ### 2.5 Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people/Jonh
# Copied file to people/Paul
# Copied file to people/Ringo

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people/Jonh/imgs/sp2273_logo.png
# Moved logo to people/Paul/imgs/sp2273_logo.png
# Moved logo to people/Ringo/imgs/sp2273_logo.png

# %% [markdown]
# ### 2.6 Listing files

# %%
glob.glob('*')
# Out:
# ['my-text-once.txt',
#  'sp2273_logo.png',
#  'spectrum-01.txt',
#  'people',
#  'my-text-lines.txt',
#  'files,_folders_and_os_(need).ipynb']

# %%
glob.glob('peo*')
# Out:
# ['people']

# %%
glob.glob('peo*/*')
# Out:
# ['people/Paul', 'people/Jonh', 'people/Ringo']

# %%
glob.glob('people/**', recursive=True)
# Out:
# ['people/',
#  'people/Paul',
#  'people/Paul/imgs',
#  'people/Paul/imgs/sp2273_logo.png',
#  'people/Jonh',
#  'people/Jonh/imgs',
#  'people/Jonh/imgs/sp2273_logo.png',
#  'people/Ringo',
#  'people/Ringo/imgs',
#  'people/Ringo/imgs/sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True)
# Out:
# ['people/Paul/imgs/sp2273_logo.png',
#  'people/Jonh/imgs/sp2273_logo.png',
#  'people/Ringo/imgs/sp2273_logo.png']

# %% [markdown]
# ### 2.7 Moving about

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/people'

# %%
os.chdir('/learning-portfolio-hanasofea/files, folders and os/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/wv/qqjm3qcj7gng87bqlsxwj3180000gn/T/ipykernel_16751/3826679540.py in <module>
# ----> 1 os.chdir('/learning-portfolio-hanasofea/files, folders and os/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/learning-portfolio-hanasofea/files, folders and os/'

# %%
os.chdir("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/wv/qqjm3qcj7gng87bqlsxwj3180000gn/T/ipykernel_16751/51255949.py in <module>
# ----> 1 os.chdir("")
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %% [markdown]
# ### 2.8 Extracting Info

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
os.path.split(path)      # Split filename from the rest
# Out:
# ('people/Ringo/imgs', 'sp2273_logo.png')

# %%
os.path.splitext(path)   # Split extension
# Out:
# ('people/Ringo/imgs/sp2273_logo', '.png')

# %%
os.path.dirname(path)    # Show the directory
# Out:
# 'people/Ringo/imgs'

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
os.remove('imgs/sp2273_logo.png')
#/people/Ringo/imgs/sp2273_logo.png

# %%
os.listdir("imgs")
# Out:
# []

# %%
os.listdir("Ringo")
# Out:
# ['imgs', 'python today']

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/people'

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os'

# %%
os.chdir('..')

# %%
os.mkdir('python today')

# %%
os.chdir('python today')

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/python today'

# %%
x=[]
for i in range(0, 51):
    x.append(f"new_directory_{i:02}")
print(x)
# Out:
# ['new_directory_00', 'new_directory_01', 'new_directory_02', 'new_directory_03', 'new_directory_04', 'new_directory_05', 'new_directory_06', 'new_directory_07', 'new_directory_08', 'new_directory_09', 'new_directory_10', 'new_directory_11', 'new_directory_12', 'new_directory_13', 'new_directory_14', 'new_directory_15', 'new_directory_16', 'new_directory_17', 'new_directory_18', 'new_directory_19', 'new_directory_20', 'new_directory_21', 'new_directory_22', 'new_directory_23', 'new_directory_24', 'new_directory_25', 'new_directory_26', 'new_directory_27', 'new_directory_28', 'new_directory_29', 'new_directory_30', 'new_directory_31', 'new_directory_32', 'new_directory_33', 'new_directory_34', 'new_directory_35', 'new_directory_36', 'new_directory_37', 'new_directory_38', 'new_directory_39', 'new_directory_40', 'new_directory_41', 'new_directory_42', 'new_directory_43', 'new_directory_44', 'new_directory_45', 'new_directory_46', 'new_directory_47', 'new_directory_48', 'new_directory_49
# ...

# %%
os.mkdir('new directory')


for number in x:
    path = os.path.join('new directory', number)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating new directory/new_directory_00
# Creating new directory/new_directory_01
# Creating new directory/new_directory_02
# Creating new directory/new_directory_03
# Creating new directory/new_directory_04
# Creating new directory/new_directory_05
# Creating new directory/new_directory_06
# Creating new directory/new_directory_07
# Creating new directory/new_directory_08
# Creating new directory/new_directory_09
# Creating new directory/new_directory_10
# Creating new directory/new_directory_11
# Creating new directory/new_directory_12
# Creating new directory/new_directory_13
# Creating new directory/new_directory_14
# Creating new directory/new_directory_15
# Creating new directory/new_directory_16
# Creating new directory/new_directory_17
# Creating new directory/new_directory_18
# Creating new directory/new_directory_19
# Creating new directory/new_directory_20
# Creating new directory/new_directory_21
# Creating new directory/new_directory_22
# ...

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/python today'

# %%
os.chdir('..')

# %%
 for i in range(1, 51, 2):
    os.rmdir(f"new_directory_{i:02}")

# %%
# !ls
# Out:
# new_directory_00 new_directory_14 new_directory_28 new_directory_42
# new_directory_02 new_directory_16 new_directory_30 new_directory_44
# new_directory_04 new_directory_18 new_directory_32 new_directory_46
# new_directory_06 new_directory_20 new_directory_34 new_directory_48
# new_directory_08 new_directory_22 new_directory_36 new_directory_50
# new_directory_10 new_directory_24 new_directory_38
# new_directory_12 new_directory_26 new_directory_40

# %%
for number in x:
    path = os.path.join('new directory', number)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'creating {path}')
# Out:
# new directory/new_directory_00 already exists; skipping creation.
# creating new directory/new_directory_01
# new directory/new_directory_02 already exists; skipping creation.
# new directory/new_directory_03 already exists; skipping creation.
# new directory/new_directory_04 already exists; skipping creation.
# creating new directory/new_directory_05
# new directory/new_directory_06 already exists; skipping creation.
# new directory/new_directory_07 already exists; skipping creation.
# new directory/new_directory_08 already exists; skipping creation.
# creating new directory/new_directory_09
# new directory/new_directory_10 already exists; skipping creation.
# new directory/new_directory_11 already exists; skipping creation.
# new directory/new_directory_12 already exists; skipping creation.
# creating new directory/new_directory_13
# new directory/new_directory_14 already exists; skipping creation.
# new directory/new_directory_15 already exists; skipping creation.
# ...

# %%
os.chdir('new directory')

# %%
for i in range(0, 51, 5):
    os.rename(f'new_directory_{i:02}', f'haha_{i:02}')

# %%
# !ls
# Out:
# haha_00          new_directory_03 new_directory_19 new_directory_36
# haha_05          new_directory_04 new_directory_21 new_directory_37
# haha_10          new_directory_06 new_directory_22 new_directory_38
# haha_15          new_directory_07 new_directory_23 new_directory_39
# haha_20          new_directory_08 new_directory_24 new_directory_41
# haha_25          new_directory_09 new_directory_26 new_directory_42
# haha_30          new_directory_11 new_directory_27 new_directory_43
# haha_35          new_directory_12 new_directory_28 new_directory_44
# haha_40          new_directory_13 new_directory_29 new_directory_46
# haha_45          new_directory_14 new_directory_31 new_directory_47
# haha_50          new_directory_16 new_directory_32 new_directory_48
# new_directory_01 new_directory_17 new_directory_33 new_directory_49
# new_directory_02 new_directory_18 new_directory_34

# %%
glob.glob('haha*/*')
# Out:
# []

# %%
os.chdir('new directory')

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/python today/new directory'

# %%
x = glob.glob('haha*')

# %%
x
# Out:
# ['haha_10',
#  'haha_45',
#  'haha_20',
#  'haha_05',
#  'haha_35',
#  'haha_50',
#  'haha_25',
#  'haha_40',
#  'haha_15',
#  'haha_30',
#  'haha_00']

# %%
for number in x:
    shutil.copy('sp2273_logo.png', number)
    print(f'copied file to {number}')
# Out:
# copied file to haha_10
# copied file to haha_45
# copied file to haha_20
# copied file to haha_05
# copied file to haha_35
# copied file to haha_50
# copied file to haha_25
# copied file to haha_40
# copied file to haha_15
# copied file to haha_30
# copied file to haha_00

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
month = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}



def name(old):
    x=old[:3]
    y=month[x]
    new = old.replace(x, y)
    return new
name('oct-08-singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
def rename_my_file(old_file_name):
    x=old_file_name[:3]
    y=month[x]
    new_file_name = old_file_name.replace(x, y)
    return new_file_name
name('oct-08-singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
old = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']


def rename_my_file(old_file_name):
    x=old_file_name[:3]
    y=month[x]
    new_file_name = old_file_name.replace(x, y)
    print(old_file_name +"---->"+ new_file_name)
    return new_file_name 
    
    
new = [rename_my_file(old_file_name) for old_file_name in old]
# Out:
# oct-08_singapore.txt---->10-08_singapore.txt
# jul-10_cairo.txt---->07-10_cairo.txt
# may-15_dhaka.txt---->05-15_dhaka.txt
# may-13_cairo.txt---->05-13_cairo.txt
# oct-21_cairo.txt---->10-21_cairo.txt
# jan-10_singapore.txt---->01-10_singapore.txt
# jun-20_tokyo.txt---->06-20_tokyo.txt
# aug-06_jakarta.txt---->08-06_jakarta.txt
# dec-21_karachi.txt---->12-21_karachi.txt
# jan-01_tokyo.txt---->01-01_tokyo.txt

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/directory to extract'

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/directory to extract'

# %%
import zipfile

# %%
files = glob.glob('*.zip')
files
# Out:
# ['os-collaboration-exercise-data.zip']

# %%
import zipfile as zf
files = zf.ZipFile("os-collaboration-exercise-data.zip", 'r')
files.extractall('directory to extract')
files.close()

# %%
os.chdir('os-collaboration-exercise-data')

# %%
glob.glob('*.txt', recursive=True)
# Out:
# ['dec-10_osaka.txt',
#  'jul-14_karachi.txt',
#  'nov-17_osaka.txt',
#  'jul-13_cairo.txt',
#  'jun-15_manila.txt',
#  'aug-20_tokyo.txt',
#  'jun-16_melbourne.txt',
#  'sep-05_tokyo.txt',
#  'jun-22_manila.txt',
#  'apr-11_shanghai.txt',
#  'sep-21_singapore.txt',
#  'feb-01_singapore.txt',
#  'may-09_manila.txt',
#  'jan-20_tokyo.txt',
#  'jan-30_manila.txt',
#  'jun-28_tokyo.txt',
#  'apr-16_shanghai.txt',
#  'dec-07_shanghai.txt',
#  'nov-03_singapore.txt',
#  'oct-07_dhaka.txt',
#  'aug-08_osaka.txt',
#  'apr-27_melbourne.txt',
#  'aug-29_karachi.txt',
#  'feb-12_dhaka.txt',
#  'oct-30_manila.txt',
#  'aug-27_dhaka.txt',
#  'jan-19_melbourne.txt',
#  'feb-13_shanghai.txt',
#  'jul-20_melbourne.txt',
#  'sep-11_tokyo.txt',
#  'aug-07_jakarta.txt',
#  'jan-08_osaka.txt',
#  'jun-25_jakarta.txt',
#  'sep-27_jakarta.txt',
#  'may-28_dhaka.txt',
#  'jul-14_jakarta.txt',
#  'oct-14_tokyo.txt',
#  'dec-04_osaka.txt',
#  'may-20_karachi.txt',
#  'aug-08_singapore.txt',
# ...

# %%
z = glob.glob('*.txt', recursive=True)

# %%
z
# Out:
# ['dec-10_osaka.txt',
#  'jul-14_karachi.txt',
#  'nov-17_osaka.txt',
#  'jul-13_cairo.txt',
#  'jun-15_manila.txt',
#  'aug-20_tokyo.txt',
#  'jun-16_melbourne.txt',
#  'sep-05_tokyo.txt',
#  'jun-22_manila.txt',
#  'apr-11_shanghai.txt',
#  'sep-21_singapore.txt',
#  'feb-01_singapore.txt',
#  'may-09_manila.txt',
#  'jan-20_tokyo.txt',
#  'jan-30_manila.txt',
#  'jun-28_tokyo.txt',
#  'apr-16_shanghai.txt',
#  'dec-07_shanghai.txt',
#  'nov-03_singapore.txt',
#  'oct-07_dhaka.txt',
#  'aug-08_osaka.txt',
#  'apr-27_melbourne.txt',
#  'aug-29_karachi.txt',
#  'feb-12_dhaka.txt',
#  'oct-30_manila.txt',
#  'aug-27_dhaka.txt',
#  'jan-19_melbourne.txt',
#  'feb-13_shanghai.txt',
#  'jul-20_melbourne.txt',
#  'sep-11_tokyo.txt',
#  'aug-07_jakarta.txt',
#  'jan-08_osaka.txt',
#  'jun-25_jakarta.txt',
#  'sep-27_jakarta.txt',
#  'may-28_dhaka.txt',
#  'jul-14_jakarta.txt',
#  'oct-14_tokyo.txt',
#  'dec-04_osaka.txt',
#  'may-20_karachi.txt',
#  'aug-08_singapore.txt',
# ...

# %%
def rename_my_file(old_file_name):
        x=old_file_name[:3]
        y=month[x]
        new_file_name = old_file_name.replace(x, y)
        return new_file_name

for old_file_name in z:
    os.rename(old_file_name, rename_my_file(old_file_name))

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/directory to extract/os-collaboration-exercise-data'

# %%
os.chdir('..')

# %%
os.mkdir('city')

for cities in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    path = os.path.join('city', cities)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating city/Cairo
# Creating city/Dhaka
# Creating city/Jakarta
# Creating city/Karachi
# Creating city/Manila
# Creating city/Melbourne
# Creating city/Osaka
# Creating city/Shanghai
# Creating city/Singapore
# Creating city/Tokyo

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/directory to extract/os-collaboration-exercise-data'

# %%
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
city_list2 = ['Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
glob.glob('*cairo.txt', recursive=True)
# Out:
# ['12-03_cairo.txt',
#  '01-30_cairo.txt',
#  '11-14_cairo.txt',
#  '04-21_cairo.txt',
#  '05-27_cairo.txt',
#  '12-17_cairo.txt',
#  '01-05_cairo.txt',
#  '08-18_cairo.txt',
#  '05-12_cairo.txt',
#  '12-22_cairo.txt',
#  '07-17_cairo.txt',
#  '04-14_cairo.txt',
#  '11-21_cairo.txt',
#  '01-11_cairo.txt',
#  '03-14_cairo.txt',
#  '08-20_cairo.txt',
#  '09-26_cairo.txt',
#  '11-19_cairo.txt',
#  '01-08_cairo.txt',
#  '09-13_cairo.txt',
#  '08-01_cairo.txt',
#  '09-07_cairo.txt',
#  '03-19_cairo.txt',
#  '04-06_cairo.txt',
#  '09-18_cairo.txt',
#  '01-03_cairo.txt',
#  '03-06_cairo.txt',
#  '03-12_cairo.txt',
#  '04-12_cairo.txt',
#  '12-05_cairo.txt',
#  '07-30_cairo.txt',
#  '07-24_cairo.txt',
#  '07-08_cairo.txt',
#  '08-07_cairo.txt',
#  '12-29_cairo.txt',
#  '08-26_cairo.txt',
#  '09-20_cairo.txt',
#  '07-29_cairo.txt',
#  '02-26_cairo.txt',
#  '04-20_cairo.txt',
#  '07-16_cairo.txt',
#  '12-23_cairo.txt',
#  '04-15_cairo.txt',
#  '01-04_cairo.txt',
#  '08-19_cairo.txt',
# ...

# %%
w=glob.glob('*cairo.*')

# %%
w
# Out:
# ['12-03_cairo.txt',
#  '01-30_cairo.txt',
#  '11-14_cairo.txt',
#  '04-21_cairo.txt',
#  '05-27_cairo.txt',
#  '12-17_cairo.txt',
#  '01-05_cairo.txt',
#  '08-18_cairo.txt',
#  '05-12_cairo.txt',
#  '12-22_cairo.txt',
#  '07-17_cairo.txt',
#  '04-14_cairo.txt',
#  '11-21_cairo.txt',
#  '01-11_cairo.txt',
#  '03-14_cairo.txt',
#  '08-20_cairo.txt',
#  '09-26_cairo.txt',
#  '11-19_cairo.txt',
#  '01-08_cairo.txt',
#  '09-13_cairo.txt',
#  '08-01_cairo.txt',
#  '09-07_cairo.txt',
#  '03-19_cairo.txt',
#  '04-06_cairo.txt',
#  '09-18_cairo.txt',
#  '01-03_cairo.txt',
#  '03-06_cairo.txt',
#  '03-12_cairo.txt',
#  '04-12_cairo.txt',
#  '12-05_cairo.txt',
#  '07-30_cairo.txt',
#  '07-24_cairo.txt',
#  '07-08_cairo.txt',
#  '08-07_cairo.txt',
#  '12-29_cairo.txt',
#  '08-26_cairo.txt',
#  '09-20_cairo.txt',
#  '07-29_cairo.txt',
#  '02-26_cairo.txt',
#  '04-20_cairo.txt',
#  '07-16_cairo.txt',
#  '12-23_cairo.txt',
#  '04-15_cairo.txt',
#  '01-04_cairo.txt',
#  '08-19_cairo.txt',
# ...

# %%
for cairo in w:
    shutil.copy(cairo, 'city/Cairo')
    print(f'copied file to city/Cairo')
# Out:
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# copied file to city/Cairo
# ...

# %%
os.getcwd()
# Out:
# '/Users/hanasofeasaktiandi/Documents/learning-portfolio-hanasofea/files, folders and os/directory to extract/os-collaboration-exercise-data'

# %%
file_list = glob.glob('*.*')

# %%
for i in city_list2:
    for c in glob.glob(f'*{i.lower()}.*'):
        new_path_of_files = os.path.join('city', i)
        shutil.move(c, new_path_of_files)
